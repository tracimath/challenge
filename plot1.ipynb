# %% [markdown]
# plot #1 section 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
#preprocessedcontaminants
NO_LU2_Pearson =[-0.123000000000000,-0.219000000000000,-0.367000000000000,-0.417000000000000,-0.429000000000000,-0.400000000000000,-0.396000000000000,-0.354000000000000,-0.350000000000000,-0.392000000000000,-0.410000000000000]
NO2_LU2_Pearson =[-0.266000000000000,-0.359000000000000,-0.497000000000000,-0.549000000000000,-0.563000000000000,-0.554000000000000,-0.552000000000000,-0.541000000000000,-0.544000000000000,-0.575000000000000,-0.596000000000000]
SO2_LU2_Pearson=[-0.223000000000000,-0.289000000000000,-0.339000000000000,-0.363000000000000,-0.393000000000000,-0.369000000000000,-0.367000000000000,-0.370000000000000,-0.361000000000000,-0.368000000000000,-0.381000000000000]
O3_LU2_Pearson =[0.0310000000000000,0.144000000000000,0.375000000000000,0.423000000000000,0.430000000000000,0.393000000000000,0.376000000000000,0.356000000000000,0.370000000000000,0.400000000000000,0.390000000000000]
PM_LU2_Pearson =[-0.296000000000000,-0.327000000000000,-0.437000000000000,-0.475000000000000,-0.489000000000000,-0.468000000000000,-0.459000000000000,-0.453000000000000,-0.455000000000000,-0.476000000000000,-0.500000000000000]
EC_LU2_Pearson =[-0.0150000000000000,-0.103000000000000,-0.247000000000000,-0.284000000000000,-0.279000000000000,-0.248000000000000,-0.264000000000000,-0.267000000000000,-0.286000000000000,-0.341000000000000,-0.378000000000000]                 

#boundingboxarrays
xdirect = [25,50,100,150,200,300,500,1000,2000,3000,5000];

# %%
print(NO_LU2_Pearson)
# Out:
# [-3.857]

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(xdirect,NO2_LU2_Pearson,'bo-',label='NO2')
plt.plot(xdirect,PM_LU2_Pearson,'ro-',label='PM2.5')
plt.plot(xdirect,NO_LU2_Pearson,'mo-',label='NO')
plt.plot(xdirect,EC_LU2_Pearson,'go-',label='EC')
plt.plot(xdirect,O3_LU2_Pearson,'co-',label='O3')
plt.plot(xdirect,SO2_LU2_Pearson,'ko-',label='SO2')

plt.ylabel('Pearson Correlation')
plt.xlabel('Footprint Scale')
plt.axis([10,10000,-0.85,0.85])
axes = plt.gca()
axes.set_xscale('log')
axes.set_title('Grass/Shrub')
plt.rcParams.update({'font.size': 14})

# Shrink current axis by 20%
box = ax.get_position()
axes.set_position([box.x0, box.y0, box.width * 0.8, box.height])
legend = axes.legend(loc='center left', shadow=True, bbox_to_anchor=(1, 0.5))


plt.show()
